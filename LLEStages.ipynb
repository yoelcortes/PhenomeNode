# %%
import phenomenode as phn
phn.preferences.light_mode()
phn.preferences.save()
M0 = phn.VLEStage()
M0.diagram(format='png', label_format='h', label_nodes=True, cluster=False)
# Out:
# (process:20136): GLib-GIO-WARNING **: 09:45:17.397: Unexpectedly, UWP app `Microsoft.ScreenSketch_11.2309.16.0_x64__8wekyb3d8bbwe' (AUMId `Microsoft.ScreenSketch_8wekyb3d8bbwe!App') supports 29 extensions but has no verbs
#
# (process:20136): GLib-GIO-WARNING **: 09:45:17.459: Unexpectedly, UWP app `Clipchamp.Clipchamp_2.8.3.0_neutral__yxz26nhyzhsrt' (AUMId `Clipchamp.Clipchamp_yxz26nhyzhsrt!App') supports 41 extensions but has no verbs

# %%
import phenomenode as phn
phn.preferences.light_mode()
phn.preferences.save()
M0 = phn.VLEStage()
M0.diagram(format='png', label_format='h', label_nodes=True, cluster=False)

# %%
import phenomenode as phn
phn.preferences.light_mode()
phn.preferences.save()
M0 = phn.LLEStage()
M0.diagram(format='png', label_format='h', label_nodes=True, cluster=False)
# Out:
# (process:25940): GLib-GIO-WARNING **: 09:45:33.570: Unexpectedly, UWP app `Microsoft.ScreenSketch_11.2309.16.0_x64__8wekyb3d8bbwe' (AUMId `Microsoft.ScreenSketch_8wekyb3d8bbwe!App') supports 29 extensions but has no verbs
#
# (process:25940): GLib-GIO-WARNING **: 09:45:33.639: Unexpectedly, UWP app `Clipchamp.Clipchamp_2.8.3.0_neutral__yxz26nhyzhsrt' (AUMId `Clipchamp.Clipchamp_yxz26nhyzhsrt!App') supports 41 extensions but has no verbs

# %%
MLLE = phn.MultiStageLLE(n_stages=3)
MLLE.diagram(format='svg')
# Out:
# (process:30340): GLib-GIO-WARNING **: 21:20:05.417: Unexpectedly, UWP app `Microsoft.ScreenSketch_11.2309.16.0_x64__8wekyb3d8bbwe' (AUMId `Microsoft.ScreenSketch_8wekyb3d8bbwe!App') supports 29 extensions but has no verbs
#
# (process:30340): GLib-GIO-WARNING **: 21:20:05.482: Unexpectedly, UWP app `Clipchamp.Clipchamp_2.8.3.0_neutral__yxz26nhyzhsrt' (AUMId `Clipchamp.Clipchamp_yxz26nhyzhsrt!App') supports 41 extensions but has no verbs

# %%
import phenomenode as phn
phn.preferences.light_mode()
phn.preferences.save()
M0 = phn.VLEStage(alg='Wang-Henke')
M0.diagram(format='png', label_nodes=True)
# Out:
# (process:40076): GLib-GIO-WARNING **: 21:20:36.586: Unexpectedly, UWP app `Microsoft.ScreenSketch_11.2309.16.0_x64__8wekyb3d8bbwe' (AUMId `Microsoft.ScreenSketch_8wekyb3d8bbwe!App') supports 29 extensions but has no verbs
#
# (process:40076): GLib-GIO-WARNING **: 21:20:36.651: Unexpectedly, UWP app `Clipchamp.Clipchamp_2.8.3.0_neutral__yxz26nhyzhsrt' (AUMId `Clipchamp.Clipchamp_yxz26nhyzhsrt!App') supports 41 extensions but has no verbs

# %%
import phenomenode as phn
MVLE = phn.MultiStageVLE(n_stages=3, alg='Wang-Henke')
MVLE.diagram(format='svg', label_nodes=False, cluster=False)
# Out:
# (process:35036): GLib-GIO-WARNING **: 09:11:11.029: Unexpectedly, UWP app `Microsoft.ScreenSketch_11.2309.16.0_x64__8wekyb3d8bbwe' (AUMId `Microsoft.ScreenSketch_8wekyb3d8bbwe!App') supports 29 extensions but has no verbs
#
# (process:35036): GLib-GIO-WARNING **: 09:11:11.098: Unexpectedly, UWP app `Clipchamp.Clipchamp_2.8.3.0_neutral__yxz26nhyzhsrt' (AUMId `Clipchamp.Clipchamp_yxz26nhyzhsrt!App') supports 41 extensions but has no verbs

# %%
import phenomenode as phn
MVLE = phn.MultiStageVLE(n_stages=3, alg='Wang-Henke')
MVLE.diagram(format='svg', label_nodes=False, cluster=False)
# Out:
# (process:27224): GLib-GIO-WARNING **: 09:45:43.346: Unexpectedly, UWP app `Microsoft.ScreenSketch_11.2309.16.0_x64__8wekyb3d8bbwe' (AUMId `Microsoft.ScreenSketch_8wekyb3d8bbwe!App') supports 29 extensions but has no verbs
#
# (process:27224): GLib-GIO-WARNING **: 09:45:43.416: Unexpectedly, UWP app `Clipchamp.Clipchamp_2.8.3.0_neutral__yxz26nhyzhsrt' (AUMId `Clipchamp.Clipchamp_yxz26nhyzhsrt!App') supports 41 extensions but has no verbs

# %%
import phenomenode as phn
MVLE = phn.MultiStageVLE(n_stages=3, alg='Wang-Henke')
MVLE.diagram(format='svg', label_nodes=False, cluster=False, filterkey=lambda x: x.category != 'material')
# Out:
# (process:23228): GLib-GIO-WARNING **: 09:47:46.750: Unexpectedly, UWP app `Microsoft.ScreenSketch_11.2309.16.0_x64__8wekyb3d8bbwe' (AUMId `Microsoft.ScreenSketch_8wekyb3d8bbwe!App') supports 29 extensions but has no verbs
#
# (process:23228): GLib-GIO-WARNING **: 09:47:46.812: Unexpectedly, UWP app `Clipchamp.Clipchamp_2.8.3.0_neutral__yxz26nhyzhsrt' (AUMId `Clipchamp.Clipchamp_yxz26nhyzhsrt!App') supports 41 extensions but has no verbs

# %%
import phenomenode as phn
with phn.PhenomeNode() as n:
    feed = phn.Stream()
    solvent = phn.Stream()
    wastewater = phn.Stream()
    glacial_acetate = phn.Stream()
    d0 = phn.Stream()
    d1 = phn.Stream()
    recycle = phn.Stream()
    water_rich = phn.Stream()
    MLLE = phn.MultiStageLLE(n_stages=3, ins=[feed, solvent, recycle], feed_stages=[0, -1, -1]) 
    LLE = phn.LLEStage(ins=[d0, d1], outs=[recycle, water_rich])
    MVLE = phn.MultiStageVLE(
        ins=[MLLE.outs[0]], outs=[d0, glacial_acetate],
        feed_stages=[1], n_stages=3, alg='Wang-Henke'
    ) 
    MVLE = phn.MultiStageVLE(
        ins=[MLLE.outs[1], water_rich], outs=[d1, wastewater],
        feed_stages=[1, 1], n_stages=3, alg='Wang-Henke'
    ) 
n.diagram(format='svg', label_nodes=False, cluster=False)
# Out:
# (process:31472): GLib-GIO-WARNING **: 18:45:18.978: Unexpectedly, UWP app `Microsoft.ScreenSketch_11.2309.16.0_x64__8wekyb3d8bbwe' (AUMId `Microsoft.ScreenSketch_8wekyb3d8bbwe!App') supports 29 extensions but has no verbs
#
# (process:31472): GLib-GIO-WARNING **: 18:45:19.044: Unexpectedly, UWP app `Clipchamp.Clipchamp_2.8.3.0_neutral__yxz26nhyzhsrt' (AUMId `Clipchamp.Clipchamp_yxz26nhyzhsrt!App') supports 41 extensions but has no verbs

# %%
n.diagram(format='svg', label_nodes=False, cluster=False, filterkey= lambda x: x.category != 'energy')

# %%
recycle.Fcp.sinks
# Out:
# deque([Composition(6), BulkComponents(4), MultiStageLLE(0)])

# %%
recycle.Fcp
# Out:
# F[c, liq, o=0, s=0]

# %%
recycle.Fcp.sources
# Out:
# deque([EQMaterialBalance(3), LLEStage(0)])

# %%
import phenomenode as phn
with phn.PhenomeNode() as n:
    n_stages = 3
    alg = 'Wang-Henke'
    feed_stages = (0, -1)
    outlet_streams = [
        [phn.Stream(), phn.Stream()] # Vapor, Liquid
        for i in range(n_stages)
    ]
    feeds_by_stage = {i: j for i, j in zip(feed_stages, self.ins)}
    inlet_streams = []
    for i in range(n_stages):
        if i == 0:
            inlets = [outlet_streams[i+1][0]]
        elif i == n_stages - 1:
            inlets = [outlet_streams[i-1][1]]
        else:
            inlets = [outlet_streams[i+1][0], outlet_streams[i-1][1]]
        if i in feeds_by_stage:
            inlets.append(feeds_by_stage[i])
        inlet_streams.append(inlets)
    stage_location = {0: 'top', n_stages-1: 'bottom'}
    self.vle_stages = [
        VLEStage(
            ins=inlet_streams[i],
            outs=outlet_streams[i],
            location=stage_location.get(i, 'middle'),
            alg=alg,
        ) for i in range(n_stages)
    ]
