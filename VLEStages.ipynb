# %%
import phenomenode as phn
phn.preferences.light_mode()
phn.preferences.save()
M0 = phn.VLEStage(alg='Wang-Henke')
M0.diagram(format='png', cluster=False, label_nodes=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 phn.preferences.light_mode()
#       3 phn.preferences.save()
# ----> 4 M0 = phn.VLEStage(alg='Wang-Henke')
#       5 M0.diagram(format='png', cluster=False, label_nodes=True)
#
# File ~\code\PhenomeNode\phenomenode\unit.py:18, in Unit.__new__(cls, ins, outs, name, index, **kwargs)
#      16 ins = [Stream() for i in range(cls.n_ins)] if ins is None else as_streams(ins)
#      17 outs = [Stream() for i in range(cls.n_outs)] if outs is None else as_streams(outs)
# ---> 18 self = super().__new__(cls, ins, outs, name, **kwargs)
#      19 return self
#
# File ~\code\PhenomeNode\phenomenode\phenomenode.py:101, in PhenomeNode.__new__(cls, ins, outs, name, **kwargs)
#      99 self.prepare(ins, outs, **kwargs)
#     100 self.registry.open_context_level()
# --> 101 self.load()
#     102 self.phenomena = self.registry.close_context_level()
#     103 for i in self.phenomena: i.ancestry.append(i)
#
# File ~\code\PhenomeNode\phenomenode\units.py:111, in VLEStage.load(self)
#     106 self.bubble_point = bubble_point = phn.BubblePoint(
#     107     ins=['zL', liquid.T, liquid.P, 'KVc'],
#     108 )
#     109 zL, T, P, KVc = bubble_point.ins
#     110 self.vle_material_balance = vle_material_balance = phn.EQMaterialBalance(
# --> 111     ins=(Fc, KVc, 'V'), outs=('FVc', FLc)
#     112 )
#     113 Fc, KVc, V = vle_material_balance.ins
#     114 FVc, FLc = vle_material_balance.outs
#
# UnboundLocalError: cannot access local variable 'FLc' where it is not associated with a value

# %%
MVLE = phn.MultiStageVLE(n_stages=3, alg='Wang-Henke')
MVLE.diagram(format='svg')
# Out:
# (process:46064): GLib-GIO-WARNING **: 18:59:17.006: Unexpectedly, UWP app `Microsoft.ScreenSketch_11.2309.16.0_x64__8wekyb3d8bbwe' (AUMId `Microsoft.ScreenSketch_8wekyb3d8bbwe!App') supports 29 extensions but has no verbs
#
# (process:46064): GLib-GIO-WARNING **: 18:59:17.069: Unexpectedly, UWP app `Clipchamp.Clipchamp_2.8.3.0_neutral__yxz26nhyzhsrt' (AUMId `Clipchamp.Clipchamp_yxz26nhyzhsrt!App') supports 41 extensions but has no verbs

# %%
MVLE = phn.MultiStageVLE(n_stages=3, alg='Wang-Henke')
MVLE.diagram(format='svg', label_nodes=False, cluster=False, filterkey=lambda x: x.category != 'energy')
# Out:
# (process:45580): GLib-GIO-WARNING **: 19:04:23.026: Unexpectedly, UWP app `Microsoft.ScreenSketch_11.2309.16.0_x64__8wekyb3d8bbwe' (AUMId `Microsoft.ScreenSketch_8wekyb3d8bbwe!App') supports 29 extensions but has no verbs
#
# (process:45580): GLib-GIO-WARNING **: 19:04:23.090: Unexpectedly, UWP app `Clipchamp.Clipchamp_2.8.3.0_neutral__yxz26nhyzhsrt' (AUMId `Clipchamp.Clipchamp_yxz26nhyzhsrt!App') supports 41 extensions but has no verbs
